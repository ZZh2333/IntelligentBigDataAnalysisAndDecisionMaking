# %% [markdown]
# # 囚徒困境演化博弈分析
# 姓名：邹子涵
# 学号：202020085400139

# %% [markdown]
# <p style="text-indent:2em"></p>

# %% [markdown]
# ## 一、囚徒困境

# %% [markdown]
# <p style="text-indent:2em">囚徒困境（prisoner's dilemma）是指两个被捕的囚徒之间的一种特殊博弈，说明为什么甚至在合作对双方都有利时，保持合作也是困难的。囚徒困境是博弈论的非零和博弈中具代表性的例子，反映个人最佳选择并非团体最佳选择。虽然困境本身只属模型性质，但现实中的价格竞争、环境保护、人际关系等方面，也会频繁出现类似情况。</p>

# %% [markdown]
# ### 1.1、理论起源
# <p style="text-indent:2em">囚徒困境的故事讲的是，两个嫌疑犯作案后被警察抓住，分别关在不同的屋子里接受审讯。警察知道两人有罪，但缺乏足够的证据。警察告诉每个人：如果两人都抵赖，各判刑一年；如果两人都坦白，各判八年；如果两人中一个坦白而另一个抵赖，坦白的放出去，抵赖的判十年。于是，每个囚徒都面临两种选择：坦白或抵赖。然而，不管同伙选择什么，每个囚徒的最优选择是坦白：如果同伙抵赖、自己坦白的话放出去，抵赖的话判十年，坦白比不坦白好；如果同伙坦白、自己坦白的话判八年，比起抵赖的判十年，坦白还是比抵赖的好。</p>

# %% [markdown]
# ![囚徒困境.jpg](attachment:64697360-6bb7-4b07-8145-161fbe9fd22f.jpg)

# %% [markdown]
# <p style="text-indent:2em">结果，两个嫌疑犯都选择坦白，各判刑八年。如果两人都抵赖，各判一年，显然这个结果好。囚徒困境所反映出的深刻问题是，人类的个人理性有时能导致集体的非理性--聪明的人类会因自己的聪明而作茧自缚，或者损害集体的利益。</p>

# %% [markdown]
# ## 二、python实现沙盒模式下囚徒困境演化过程

# %% [markdown]
# ### 2.1、过程构思
# 在沙盒模式下，初始化数个拥有不同策略、初始个数相同的人群，使他们在沙盒中随机进行博弈数轮，每轮结束后淘汰一定比例得分较低的人数，并在博弈过程中加入随机变异。

# %% [markdown]
# ### 2.2、代码解读

# %% [markdown]
# #### 2.2.1、导包并初始化囚徒选择
# 将BETRAY（背叛）定义为False
# COOPERATE（合作）定义为True

# %%
import random
from collections import Counter
import matplotlib.pyplot as plt
import sys
import inspect

BETRAY = True
COOPERATE = False

# %% [markdown]
# 工具函数takeSecond(elem)，用于获取列表的第二个元素

# %%
def takeSecond(elem):
    return elem[1]

# %% [markdown]
# #### 2.2.2、定义策略母类
# 在策略母类中定义了以下几个方法：

# %% [markdown]
# + get_score:得分方法，当自身得分长度大于50时。将得分进行累加
# + __init__：初始化方法，包含三个参数：my_history/theirhistory/score，分别用来记录自身最后的选择、上一博弈对手的选择以及得分情况
# + play：博弈方法
# + reinit_history：重新初始化，重置自身最后的选择和上一博弈对手的选择

# %%
class Alg:

    def get_score(self):
        if len(self.score)>50:
            self.score = [sum(self.score)]
        return self.score

    def __init__(self):
        self.my_history = []
        self.their_history = []
        self.score = []

    def play(self):
        raise NotImplementedError

    def __repr__(self):
        return "{}".format(type(self).__name__)

    def reinit_history(self):
        self.my_history = []
        self.their_history = []
        return self

# %% [markdown]
# #### 2.2.3、定义分组方法
# 该方法的目标是将列表ls中的人群按照size大小进行切分分组。

# %%
def partition(ls, size):
    return [ls[i:i + size] for i in range(0, len(ls), size)]

# %% [markdown]
# 测试案例：

# %%
# list = partition([1,2,3,4,5,6,7,8,9,1],3)
# print(list)

# %% [markdown]
# #### 2.2.4、定义囚徒困境的收益矩阵
# 这里通过将囚徒困境的收益矩阵给改为正值，方便计算并比较得分情况，更改后的囚徒困境收益矩阵为下图所示：

# %% [markdown]
# ![囚徒困境收益矩阵（正）.png](attachment:cfc1c0be-20cc-4ea4-a507-0a4f67a1f7f6.png)

# %%
def score(A_choice, B_choice):
    if A_choice == B_choice:
        if A_choice == BETRAY:
            return (1, 1)
        return (3, 3)
    if A_choice == BETRAY:
        return (5, 0)
    return (0, 5)

# %% [markdown]
# #### 2.2.5、定义博弈过程
# A与B博弈，将自己的选择记录在my_history中，将对方的选择记录在their_history中，并将A、B的得分记录在score中。

# %%
def play(A, B):
    A_score = 0
    B_score = 0
    A_choice = A.play(A.my_history, B.my_history)
    B_choice = B.play(B.my_history, A.my_history)
    A_score_, B_score_ = score(A_choice, B_choice)
    A.my_history.append(A_choice)
    B.my_history.append(B_choice)
    A.their_history.append(B_choice)
    B.their_history.append(A_choice)
    A.score.append(A_score_)
    B.score.append(B_score_)
    return (A_score_, B_score_)

# %% [markdown]
# #### 2.2.6、定义沙盒模式
# 在沙盒模式中会将所有人进行两两分组————partition(persons, 2)，persons为参与博弈的所有人群对象，rounds为博弈轮数。
# 在每一轮中，对分好组的两人进行一次博弈

# %%
# 一期博弈过程，即所有样本随机两两匹配后博弈rounds次
def simulate(persons, rounds, seed=0):
    random.shuffle(persons)
    persons_pairs = partition(persons, 2)
    for i in range(rounds):
        for pair in persons_pairs:
            play(pair[0], pair[1])

# %% [markdown]
# #### 2.2.7、沙盒世界更新
# 在每轮博弈完成后，会对沙盒世界中的人群对象进行更新，包括策略变更、淘汰和生成新的样本（新加入的玩家）

# %%
def self_reproduction(persons, mutation_rate, out_rate):
#     按照变异比率获取当前人数中变更策略的对象数量
    mutation_count = int(len(persons) * mutation_rate)
#     按照淘汰比率获取当前人数中被淘汰的对象数量
    out_count = int(len(persons) * out_rate)
    for person in persons:
        score_list = [sum(person.get_score()) for person in persons]
#     将人群按照得分顺序进行排列
    persons.sort(key=lambda x: sum(x.get_score()), reverse=True)
    score_sorted = [sum(person.get_score()) for person in persons]
#     获取淘汰样本及变异样本
    out_persons = persons[-out_count:]
    random.shuffle(out_persons)
    mutation_persons = out_persons[:mutation_count]
#     淘汰样本，切分列表
    persons = persons[:-out_count]
#     针对淘汰样本中未变异的生成新样本，针对变异样本随机生成新样本后my_history及their_history传递
    out2reinit = [eval(person.__repr__() + "()") for person in persons[:out_count - mutation_count]]
    for person in out2reinit:
        person.my_history = []
        person.their_history = []
    out2mutation = []
    for person in mutation_persons:
        algs = Alg.__subclasses__()
        new_person = random.choice(algs)()
        out2mutation.append(new_person)
#     新旧样本组成新的persons
    print("out2reinit：", out2reinit)
    print("out2mutation：", out2mutation)
    print ("persons：", persons)
    persons = persons + out2reinit + out2mutation
    persons = [person.reinit_history() for person in persons]
    return persons

# %% [markdown]
# #### 2.2.8、定义不同的策略

# %% [markdown]
# 背叛策略，该策略的样本会永远选择背叛

# %%
class Betray(Alg):
    def play(self, my_history, their_history):
        return BETRAY

# %% [markdown]
# 合作策略，该策略的样本会永远选择合作

# %%
class Cooperate(Alg):
    def play(self, my_history, their_history):
        return COOPERATE

# %% [markdown]
# 报复策略，该策略的样本一开始会选择合作并在后续的选择中倾向于合作，但是如果上一次博弈对手选择了背叛，那么这一次则会选择背叛

# %%
class Tit4Tat(Alg):
    def play(self, my_history, their_history):
        if len(their_history) <= 1:
            return COOPERATE
        if their_history[-1] == BETRAY:
            return BETRAY
        return COOPERATE

# %% [markdown]
# 混沌随机策略，该策略的样本会以1/3的概率选择背叛，以2/3的概率选择合作

# %%
class RandomKind(Alg):
    def play(self, my_history, their_history):
        if random.random() < 0.667:
            return COOPERATE
        return BETRAY

# %% [markdown]
# 秩序随机策略，该策略的样本会以1/3的概率选择合作，以2/3的概率选择背叛

# %%
class RandomNasty(Alg):
    def play(self, my_history, their_history):
        if random.random() < 0.667:
            return BETRAY
        return COOPERATE

# %% [markdown]
# 理智策略，该策略的样本回一句对手的选择做出改变，如果对手有超过半数的选择选择背叛，那么自己将会选择背叛，否则将选择合作

# %%
class Dirk(Alg):
    def play(self, my_history, their_history):
        cnt_betray = len([x for x in their_history if x == BETRAY])
        if cnt_betray > 0.5 * len(their_history):
            return BETRAY
        return COOPERATE

# %% [markdown]
# 秩序规律策略，该策略的样本以三次博弈为循环，每轮循环中前两次博弈选择合作，第三次选择背叛

# %%
class PerKind(Alg):
    def play(self, my_history, their_history):
        m = len(their_history) % 3
        if m == 0 or m == 1:
            return COOPERATE
        return BETRAY

# %% [markdown]
# 混沌规律策略，该策略的样本以三次博弈为循环，每轮循环中前两次博弈选择背叛，第三次选择合作

# %%
class PerNasty(Alg):
    def play(self, my_history, their_history):
        m = len(their_history) % 3
        if m == 0 or m == 1:
            return BETRAY
        return COOPERATE

# %% [markdown]
# 叛逆策略，该策略的样本会在首次选择背叛，第二次会依据对方的第一次选择做出相反的选择，在往后的选择会依据对手最后两次的选择做出抉择，一旦有背叛行为，将会选择合作

# %%
class Theresa(Alg):
    def play(self, my_history, their_history):
        if len(their_history) == 0:
            return BETRAY
        if len(their_history) == 1:
            if their_history[-1] == BETRAY:
                return COOPERATE
            return BETRAY
        if their_history[-1] == BETRAY or their_history[-2] == BETRAY:
            return COOPERATE
        return BETRAY

# %% [markdown]
# 奇偶策略，该策略的样本会在单数次选择背叛、双数次选择合作

# %%
class Alternate(Alg):
    def play(self, my_history, their_history):
        m = len(their_history) % 2
        if m == 0:
            return BETRAY
        return COOPERATE

# %% [markdown]
# 复杂策略，过于复杂。

# %%
class WinStayLoseShift(Alg):
    def play(self, my_history, their_history):
        if len(their_history) == 0:
            return COOPERATE
        if len(my_history) == 0:
            return COOPERATE
        if my_history[-1] == COOPERATE and their_history[-1] == COOPERATE:
            return COOPERATE
        if my_history[-1] == COOPERATE and their_history[-1] == BETRAY:
            return BETRAY
        if my_history[-1] == BETRAY and their_history[-1] == COOPERATE:
            return BETRAY
        return COOPERATE

# %% [markdown]
# #### 2.2.9、生成策略样本
# 依据传入的参数counts对每个策略生成counts人数

# %%
# 生成策略样本
def creat_persons(counts):
    inst = []
    for i in range(counts):
        examples = Alg.__subclasses__()
        inst += [example() for example in examples]
    # print(inst)
    return inst

# %% [markdown]
# 测试

# %%
# test = creat_persons(2)
# test

# %% [markdown]
# 测试中可以看到每个策略都生成了2个样本

# %% [markdown]
# ### 2.3、绘图并分析
# 这里的超级参数选择如下：演化代数为10代，每代进行20期，每期进行10次重复博弈，每种策略的初始样本数量为50人，每代都会进行策略变异、淘汰样本及更新新样本，淘汰率为0.2，变异概率为0.05。

# %% [markdown]
# #### 2.3.1、绘制沙盒最终策略人群饼状图
# 将最终沙盒中的不同策略人群按照比例绘制饼状图，传入参数为persons_strategy: 各期样本分布列表；i: 绘制期数。

# %%
def plot_persons_of_strategy(persons_strategy, i):
    plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
    labels = persons_strategy[i - 1].keys()
    sizes = persons_strategy[i - 1].values()
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=False, startangle=150)
    plt.title("第" + str(i) + "期样本分布（淘汰更新前）")
    plt.show()
    return

# %% [markdown]
# ![新样本分布.png](attachment:554f338f-35a1-4431-8c35-e0be95c77dc7.png)

# %% [markdown]
# #### 2.3.2、输出沙盒最终各策略的得分平均数
# 传入参数为persons_score:各期策略平均分数；i:绘制期数。

# %%
def plot_persons_of_score(persons_score, i):
    dict = persons_score[i - 1]
    print(dict)
    dict2 = sorted(zip(dict.values(), dict.keys()), reverse=True)
#     plt.show()
    return

# %% [markdown]
# #### 2.3.3、绘制博弈过程不同策略样本的数量
# 由于每代会进行淘汰和更新，因此每代的策略样本数量都会发生变化，用折线图绘制出策略样本数量的变化

# %%
def plot_persons_of_counts(persons_strategy):
    labels = persons_strategy[0].keys()
    dict = {key: [] for key in labels}
    for d in persons_strategy:
        for key in d:
            dict[key].append(d[key])
    print (dict)
    names = list(range(0, len(persons_strategy)))
    x = range(len(names))
    plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
    colorList = ["#ed1299", "#09f9f5", "#246b93", "#cc8e12", "#d561dd", "#c93f00", "#ddd53e",
                "#4aef7b", "#e86502", "#9ed84e", "#39ba30", "#6ad157", "#8249aa", "#99db27", "#e07233", "#ff523f",
                "#ce2523", "#f7aa5d", "#cebb10", "#03827f", "#931635", "#373bbf", "#a1ce4c", "#ef3bb6", "#d66551",

                 ]
    i = 0
    for key in dict:
        plt.plot(x, dict[key], c=colorList[i],  label="$"+key+"$")
        i += 1
    plt.legend(loc='center left', bbox_to_anchor=(0, 1.05), ncol=5)  # 让图例生效
    plt.xticks(x, names, rotation=1)

    plt.margins(0.01)
    plt.subplots_adjust(bottom=0.10)
    plt.xlabel('代数')  # X轴标签
    plt.ylabel("策略样本数")  # Y轴标签
    plt.show()
    return

# %% [markdown]
# ![新迭代趋势.png](attachment:333750f7-79fd-4c63-b954-a74affa59c11.png)

# %% [markdown]
# #### 2.3.4、绘制样本选择分布情况

# %%
def plot_persons_of_choice(persons_choice, i):
    plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签

    labels = persons_choice[i - 1].keys()
    sizes = persons_choice[i - 1].values()
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=False, startangle=150)
    plt.title("第" + str(i) + "代样本选择分布")
    plt.show()
    return

# %% [markdown]
# ![新样本选择分布.png](attachment:14a743d3-b04d-4f7b-bc3d-f78225f47373.png)

# %% [markdown]
# #### 2.3.5、启动沙盒博弈过程主函数

# %%
if __name__ == '__main__':
#     Num_of_generation 演化代数
    Num_of_generation = 10
#     Num_of_periods 每代期数
    Num_of_periods = 20
#     Play_num_of_per_period 每期重复博弈次数
    Play_num_of_per_period = 10
#     Num_of_per_strategy 每种策略样本初始数
    Num_of_per_strategy = 50
#     Out_rate 淘汰率
    Out_rate = 0.4
#     Mutation_rate 变异率
    Mutation_rate = 0.05

#     初始化列表
    persons_strategy = []
    persons_score = []
    persons_choice = []
#     生成样本
    persons = creat_persons(Num_of_per_strategy)
#     开始博弈
    for j in range(Num_of_generation):
        for i in range(Num_of_periods):
            print (j,"代,", i,"期")
            simulate(persons, Play_num_of_per_period, seed=0)
            # for person in persons:
            #     print (person.__repr__(), "score", sum(person.get_score()), "\n", person.my_history, "\n", person.their_history)
            # break
#         计算最终策略分布
        persons_strategy.append(Counter([person.__repr__() for person in persons]))
#         计算最终策略得分均值
        strategy_name = Counter([person.__repr__() for person in persons]).keys()
        tmp = dict.fromkeys(strategy_name, 0)
        for person in persons:
            tmp[person.__repr__()] += sum(person.get_score())
        for key in tmp:
            tmp[key] = tmp[key] / persons_strategy[j][key]
        persons_score.append(tmp)
        # 计算最终样本选择分布
        choice_list = []
        for person in persons:
            choice_list += person.my_history
        persons_choice.append(Counter(choice_list))

        persons = self_reproduction(persons, Mutation_rate, Out_rate)


    plot_persons_of_choice(persons_choice, Num_of_generation)
    plot_persons_of_strategy(persons_strategy, Num_of_generation)
    plot_persons_of_counts(persons_strategy)
    plot_persons_of_score(persons_score, Num_of_generation)
# Out:
# 0 代, 0 期
# 0 代, 1 期
# 0 代, 2 期
# 0 代, 3 期
# 0 代, 4 期
# 0 代, 5 期
# 0 代, 6 期
# 0 代, 7 期
# 0 代, 8 期
# 0 代, 9 期
# 0 代, 10 期
# 0 代, 11 期
# 0 代, 12 期
# 0 代, 13 期
# 0 代, 14 期
# 0 代, 15 期
# 0 代, 16 期
# 0 代, 17 期
# 0 代, 18 期
# 0 代, 19 期
# out2reinit： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, WinStayLoseShift, Betray, RandomNasty, Betray, PerNasty, RandomNasty, Theresa, WinStayLoseShift, Theresa, RandomNasty, Betray, Betray, Betray, Betray, Betray, Betray, Theresa, RandomNasty, Theresa, PerKind, Betray, Betray, Theresa, PerNasty, Theresa, PerNasty, Betray, Alternate, WinStayLoseShift, Betray, Betray, RandomKind, Alternate, PerNasty, Betray, WinStayLoseShift, RandomNasty, Betray, Dirk, Theresa, Alternate, RandomNasty, Betray, WinStayLoseShift, Alternate, Alternate, RandomNasty, PerNasty, PerNasty, RandomNasty, Betray, WinStayLoseShift, RandomKind, WinStayLoseShift, RandomKind, Betray, PerNasty, WinStayLoseShift, Alternate, WinStayLoseShift, RandomNasty, RandomNasty, Alternate, PerNasty, Betray, WinStayLoseShift, Theresa, WinStayLoseShift, Alternate, WinStayLoseShift, Betray, Alternate, Betray, Betray, Betray, WinStayLoseShift, PerNasty, RandomKind, PerNasty, Betray, Theresa, WinStayLoseShift, WinStayLoseShift, PerNasty, WinStayLoseShift, PerNasty, Theresa, Theresa, RandomKind, Betray, WinStayLoseShift, Tit4Tat, Alternate, WinStayLoseShift, Tit4Tat, Betray, WinStayLoseShift, Alternate, RandomNasty, RandomNasty, Alternate, Alternate, PerNasty, WinStayLoseShift, Tit4Tat, PerKind, Alternate, RandomNasty, Theresa, RandomKind, Betray, PerNasty, Alternate, Alternate, Alternate, Tit4Tat, Theresa, Theresa, Tit4Tat, RandomNasty, PerNasty, PerKind, Theresa, Dirk, Tit4Tat, RandomNasty, Alternate, Alternate, Tit4Tat, WinStayLoseShift, RandomNasty, PerKind, RandomNasty, Betray, Alternate, WinStayLoseShift, Theresa, PerNasty, Alternate, Alternate, Alternate, Alternate, PerKind, Tit4Tat, Betray, Tit4Tat, RandomNasty, WinStayLoseShift, Alternate, WinStayLoseShift, RandomKind, Alternate, Dirk, PerNasty, Tit4Tat, PerKind, RandomNasty, WinStayLoseShift, PerNasty, Betray, RandomKind, PerNasty, Betray, RandomNasty, Tit4Tat, PerKind, Tit4Tat, Betray, PerNasty, PerKind, Alternate, PerNasty, PerKind, PerKind, Theresa, Dirk, RandomNasty, Alternate, Alternate, RandomNasty, PerNasty, PerKind, Betray, WinStayLoseShift, PerNasty, Alternate]
# out2mutation： [Alternate, PerNasty, Theresa, Betray, Dirk, RandomKind, PerNasty, WinStayLoseShift, PerKind, Dirk, Alternate, Tit4Tat, Betray, RandomKind, PerNasty, RandomNasty, Cooperate, RandomNasty, Tit4Tat, Alternate, Dirk, RandomKind, RandomNasty, PerKind, Tit4Tat, Theresa, Betray]
# persons： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, WinStayLoseShift, Betray, RandomNasty, Betray, PerNasty, RandomNasty, Theresa, WinStayLoseShift, Theresa, RandomNasty, Betray, Betray, Betray, Betray, Betray, Betray, Theresa, RandomNasty, Theresa, PerKind, Betray, Betray, Theresa, PerNasty, Theresa, PerNasty, Betray, Alternate, WinStayLoseShift, Betray, Betray, RandomKind, Alternate, PerNasty, Betray, WinStayLoseShift, RandomNasty, Betray, Dirk, Theresa, Alternate, RandomNasty, Betray, WinStayLoseShift, Alternate, Alternate, RandomNasty, PerNasty, PerNasty, RandomNasty, Betray, WinStayLoseShift, RandomKind, WinStayLoseShift, RandomKind, Betray, PerNasty, WinStayLoseShift, Alternate, WinStayLoseShift, RandomNasty, RandomNasty, Alternate, PerNasty, Betray, WinStayLoseShift, Theresa, WinStayLoseShift, Alternate, WinStayLoseShift, Betray, Alternate, Betray, Betray, Betray, WinStayLoseShift, PerNasty, RandomKind, PerNasty, Betray, Theresa, WinStayLoseShift, WinStayLoseShift, PerNasty, WinStayLoseShift, PerNasty, Theresa, Theresa, RandomKind, Betray, WinStayLoseShift, Tit4Tat, Alternate, WinStayLoseShift, Tit4Tat, Betray, WinStayLoseShift, Alternate, RandomNasty, RandomNasty, Alternate, Alternate, PerNasty, WinStayLoseShift, Tit4Tat, PerKind, Alternate, RandomNasty, Theresa, RandomKind, Betray, PerNasty, Alternate, Alternate, Alternate, Tit4Tat, Theresa, Theresa, Tit4Tat, RandomNasty, PerNasty, PerKind, Theresa, Dirk, Tit4Tat, RandomNasty, Alternate, Alternate, Tit4Tat, WinStayLoseShift, RandomNasty, PerKind, RandomNasty, Betray, Alternate, WinStayLoseShift, Theresa, PerNasty, Alternate, Alternate, Alternate, Alternate, PerKind, Tit4Tat, Betray, Tit4Tat, RandomNasty, WinStayLoseShift, Alternate, WinStayLoseShift, RandomKind, Alternate, Dirk, PerNasty, Tit4Tat, PerKind, RandomNasty, WinStayLoseShift, PerNasty, Betray, RandomKind, PerNasty, Betray, RandomNasty, Tit4Tat, PerKind, Tit4Tat, Betray, PerNasty, PerKind, Alternate, PerNasty, PerKind, PerKind, Theresa, Dirk, RandomNasty, Alternate, Alternate, RandomNasty, PerNasty, PerKind, Betray, WinStayLoseShift, PerNasty, Alternate, Tit4Tat, Theresa, Alternate, RandomNasty, RandomKind, PerKind, Theresa, Alternate, Theresa, Dirk, RandomNasty, WinStayLoseShift, Dirk, RandomNasty, Tit4Tat, RandomKind, RandomKind, Alternate, RandomNasty, PerNasty, Tit4Tat, RandomNasty, PerKind, PerNasty, Tit4Tat, Betray, Alternate, Betray, Betray, Betray, RandomNasty, Theresa, PerNasty, PerKind, RandomKind, PerKind, Theresa, Dirk, PerKind, Tit4Tat, RandomKind, PerNasty, Tit4Tat, PerNasty, PerKind, Dirk, Betray, Betray, PerKind, Tit4Tat, WinStayLoseShift, RandomKind, PerNasty, PerNasty, Tit4Tat, PerNasty, WinStayLoseShift, Theresa, PerKind, PerKind, WinStayLoseShift, Theresa, PerNasty, Alternate, Betray, PerNasty, Theresa, WinStayLoseShift, RandomKind, RandomKind, Cooperate, Alternate, Alternate, Tit4Tat, Tit4Tat, Alternate, Betray, WinStayLoseShift, Alternate, WinStayLoseShift, Theresa, RandomKind, RandomKind, WinStayLoseShift, RandomNasty, RandomKind, PerNasty, Theresa, Theresa, PerKind, RandomNasty, RandomKind, RandomNasty, RandomNasty, Dirk, Tit4Tat, PerKind, RandomKind, RandomKind, Dirk, RandomNasty, PerKind, Alternate, Betray, Dirk, Tit4Tat, PerKind, Dirk, Alternate, PerKind, WinStayLoseShift, Dirk, RandomNasty, PerNasty, Theresa, RandomNasty, PerKind, RandomKind, Dirk, RandomNasty, WinStayLoseShift, RandomNasty, Dirk, WinStayLoseShift, Dirk, PerKind, Tit4Tat, Theresa, Theresa, Tit4Tat, Tit4Tat, Dirk, Dirk, PerKind, Tit4Tat, WinStayLoseShift, WinStayLoseShift]
# 1 代, 0 期
# 1 代, 1 期
# 1 代, 2 期
# 1 代, 3 期
# 1 代, 4 期
# 1 代, 5 期
# 1 代, 6 期
# 1 代, 7 期
# 1 代, 8 期
# 1 代, 9 期
# 1 代, 10 期
# 1 代, 11 期
# 1 代, 12 期
# 1 代, 13 期
# 1 代, 14 期
# 1 代, 15 期
# 1 代, 16 期
# 1 代, 17 期
# 1 代, 18 期
# 1 代, 19 期
# out2reinit： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, RandomNasty, Betray, Betray, PerNasty, RandomNasty, PerNasty, Betray, WinStayLoseShift, RandomNasty, PerNasty, Betray, Betray, Betray, RandomNasty, Betray, WinStayLoseShift, Betray, Betray, Betray, Betray, Betray, Alternate, PerNasty, Betray, Betray, Betray, PerNasty, WinStayLoseShift, Alternate, RandomNasty, RandomNasty, PerNasty, Betray, Alternate, Betray, RandomNasty, WinStayLoseShift, PerNasty, Betray, Betray, Theresa, Betray, PerNasty, WinStayLoseShift, Betray, Betray, Betray, Alternate, PerNasty, WinStayLoseShift, RandomKind, RandomNasty, RandomNasty, Betray, WinStayLoseShift, Tit4Tat, RandomNasty, RandomNasty, Alternate, WinStayLoseShift, WinStayLoseShift, Theresa, PerNasty, Betray, Alternate, RandomNasty, PerNasty, Alternate, PerNasty, WinStayLoseShift, Betray, Betray, Betray, PerNasty, Alternate, RandomNasty, PerNasty, Betray, PerNasty, Alternate, Alternate, Alternate, WinStayLoseShift, RandomNasty, WinStayLoseShift, PerNasty, Theresa, PerNasty, Betray, Betray, PerNasty, PerNasty, PerNasty, RandomNasty, WinStayLoseShift, PerNasty, WinStayLoseShift, PerNasty, Alternate, WinStayLoseShift, RandomNasty, Alternate, PerNasty, Tit4Tat, WinStayLoseShift, PerNasty, RandomNasty, Alternate, Betray, Tit4Tat, RandomKind, Theresa, Theresa, PerNasty, Alternate, Alternate, RandomNasty, Tit4Tat, Alternate, Tit4Tat, WinStayLoseShift, WinStayLoseShift, RandomNasty, Alternate, RandomKind, Dirk, PerNasty, WinStayLoseShift, Alternate, WinStayLoseShift, WinStayLoseShift, Alternate, PerNasty, Alternate, Alternate, Betray, WinStayLoseShift, WinStayLoseShift, PerNasty, Alternate, RandomNasty, Tit4Tat, Alternate, PerNasty, Tit4Tat, Alternate, Alternate, Tit4Tat, Tit4Tat, Theresa, Tit4Tat, WinStayLoseShift, Theresa, PerNasty, Alternate, PerKind, Theresa, Theresa, Tit4Tat, RandomNasty, WinStayLoseShift, Alternate, Tit4Tat, RandomNasty, RandomNasty, Tit4Tat, Theresa, Theresa, RandomKind, RandomNasty, RandomKind, PerKind, RandomNasty, PerKind, Theresa, PerNasty, Theresa]
# out2mutation： [Betray, Tit4Tat, WinStayLoseShift, PerKind, Betray, Cooperate, Alternate, Theresa, PerNasty, Cooperate, PerNasty, RandomNasty, WinStayLoseShift, Betray, Cooperate, Dirk, PerNasty, Tit4Tat, Dirk, Theresa, RandomKind, PerNasty, Cooperate, Cooperate, Cooperate, Betray, Betray]
# persons： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, RandomNasty, Betray, Betray, PerNasty, RandomNasty, PerNasty, Betray, WinStayLoseShift, RandomNasty, PerNasty, Betray, Betray, Betray, RandomNasty, Betray, WinStayLoseShift, Betray, Betray, Betray, Betray, Betray, Alternate, PerNasty, Betray, Betray, Betray, PerNasty, WinStayLoseShift, Alternate, RandomNasty, RandomNasty, PerNasty, Betray, Alternate, Betray, RandomNasty, WinStayLoseShift, PerNasty, Betray, Betray, Theresa, Betray, PerNasty, WinStayLoseShift, Betray, Betray, Betray, Alternate, PerNasty, WinStayLoseShift, RandomKind, RandomNasty, RandomNasty, Betray, WinStayLoseShift, Tit4Tat, RandomNasty, RandomNasty, Alternate, WinStayLoseShift, WinStayLoseShift, Theresa, PerNasty, Betray, Alternate, RandomNasty, PerNasty, Alternate, PerNasty, WinStayLoseShift, Betray, Betray, Betray, PerNasty, Alternate, RandomNasty, PerNasty, Betray, PerNasty, Alternate, Alternate, Alternate, WinStayLoseShift, RandomNasty, WinStayLoseShift, PerNasty, Theresa, PerNasty, Betray, Betray, PerNasty, PerNasty, PerNasty, RandomNasty, WinStayLoseShift, PerNasty, WinStayLoseShift, PerNasty, Alternate, WinStayLoseShift, RandomNasty, Alternate, PerNasty, Tit4Tat, WinStayLoseShift, PerNasty, RandomNasty, Alternate, Betray, Tit4Tat, RandomKind, Theresa, Theresa, PerNasty, Alternate, Alternate, RandomNasty, Tit4Tat, Alternate, Tit4Tat, WinStayLoseShift, WinStayLoseShift, RandomNasty, Alternate, RandomKind, Dirk, PerNasty, WinStayLoseShift, Alternate, WinStayLoseShift, WinStayLoseShift, Alternate, PerNasty, Alternate, Alternate, Betray, WinStayLoseShift, WinStayLoseShift, PerNasty, Alternate, RandomNasty, Tit4Tat, Alternate, PerNasty, Tit4Tat, Alternate, Alternate, Tit4Tat, Tit4Tat, Theresa, Tit4Tat, WinStayLoseShift, Theresa, PerNasty, Alternate, PerKind, Theresa, Theresa, Tit4Tat, RandomNasty, WinStayLoseShift, Alternate, Tit4Tat, RandomNasty, RandomNasty, Tit4Tat, Theresa, Theresa, RandomKind, RandomNasty, RandomKind, PerKind, RandomNasty, PerKind, Theresa, PerNasty, Theresa, Theresa, PerKind, Tit4Tat, Tit4Tat, Tit4Tat, Alternate, Dirk, RandomNasty, WinStayLoseShift, RandomNasty, PerKind, WinStayLoseShift, PerKind, Alternate, PerKind, Dirk, RandomNasty, RandomKind, RandomNasty, WinStayLoseShift, PerKind, RandomNasty, WinStayLoseShift, PerNasty, RandomKind, Alternate, RandomKind, Alternate, PerNasty, Tit4Tat, WinStayLoseShift, Alternate, RandomKind, PerKind, WinStayLoseShift, WinStayLoseShift, Dirk, WinStayLoseShift, PerNasty, Theresa, Tit4Tat, Tit4Tat, PerKind, WinStayLoseShift, PerKind, PerNasty, Tit4Tat, PerKind, Tit4Tat, Tit4Tat, WinStayLoseShift, WinStayLoseShift, PerKind, RandomKind, WinStayLoseShift, PerKind, WinStayLoseShift, Theresa, WinStayLoseShift, RandomKind, Alternate, RandomNasty, PerKind, Dirk, Tit4Tat, Tit4Tat, Alternate, Dirk, RandomKind, PerKind, Tit4Tat, RandomKind, Alternate, Alternate, RandomKind, PerKind, PerKind, RandomKind, Theresa, Tit4Tat, Dirk, RandomNasty, RandomNasty, Tit4Tat, Theresa, Dirk, Theresa, RandomKind, RandomNasty, PerKind, Dirk, PerKind, Alternate, PerKind, Alternate, PerKind, Dirk, PerKind, Alternate, Dirk, RandomKind, RandomNasty, Dirk, PerKind, Theresa, RandomKind, RandomKind, RandomKind, RandomNasty, Dirk, Theresa, RandomNasty, Tit4Tat, PerKind, PerKind, Dirk, Dirk, PerKind, RandomKind, Dirk, Theresa, Theresa, Theresa, Theresa, RandomKind, Dirk, RandomKind, Theresa, PerKind, Theresa, Theresa, Alternate, Dirk, Theresa, Theresa, Theresa, Cooperate]
# 2 代, 0 期
# 2 代, 1 期
# 2 代, 2 期
# 2 代, 3 期
# 2 代, 4 期
# 2 代, 5 期
# 2 代, 6 期
# 2 代, 7 期
# 2 代, 8 期
# 2 代, 9 期
# 2 代, 10 期
# 2 代, 11 期
# 2 代, 12 期
# 2 代, 13 期
# 2 代, 14 期
# 2 代, 15 期
# 2 代, 16 期
# 2 代, 17 期
# 2 代, 18 期
# 2 代, 19 期
# out2reinit： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, RandomNasty, PerNasty, PerNasty, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, WinStayLoseShift, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, PerNasty, PerNasty, Betray, RandomNasty, WinStayLoseShift, Betray, RandomNasty, PerNasty, Betray, Betray, Betray, Betray, WinStayLoseShift, Betray, RandomNasty, PerNasty, RandomNasty, Betray, Alternate, Betray, Alternate, RandomNasty, Betray, RandomNasty, WinStayLoseShift, WinStayLoseShift, RandomNasty, PerNasty, PerNasty, Alternate, PerNasty, PerNasty, WinStayLoseShift, PerNasty, PerNasty, Betray, Betray, Alternate, RandomNasty, PerNasty, Alternate, RandomNasty, RandomNasty, RandomNasty, PerNasty, Alternate, WinStayLoseShift, RandomNasty, PerNasty, WinStayLoseShift, RandomNasty, RandomNasty, PerNasty, PerNasty, PerNasty, RandomNasty, PerNasty, WinStayLoseShift, WinStayLoseShift, Alternate, PerNasty, Alternate, Alternate, Alternate, Alternate, WinStayLoseShift, WinStayLoseShift, Alternate, PerNasty, WinStayLoseShift, Alternate, RandomNasty, Alternate, RandomNasty, Alternate, Alternate, PerNasty, WinStayLoseShift, Tit4Tat, WinStayLoseShift, PerNasty, WinStayLoseShift, Alternate, RandomNasty, WinStayLoseShift, Alternate, WinStayLoseShift, PerNasty, WinStayLoseShift, Alternate, Tit4Tat, WinStayLoseShift, WinStayLoseShift, Alternate, RandomNasty, PerNasty, Tit4Tat, PerNasty, PerNasty, WinStayLoseShift, RandomNasty, RandomKind, PerNasty, Theresa, WinStayLoseShift, Tit4Tat, WinStayLoseShift, RandomNasty, Tit4Tat, Alternate, WinStayLoseShift, PerNasty, RandomNasty, Dirk, RandomNasty, WinStayLoseShift, Tit4Tat, PerNasty, RandomNasty, RandomKind, Theresa, Alternate, Tit4Tat, Alternate, Alternate, RandomKind, Alternate, Alternate, WinStayLoseShift, Tit4Tat, WinStayLoseShift, Tit4Tat, Alternate, Tit4Tat, Theresa, Alternate, RandomNasty, Tit4Tat, PerNasty, RandomNasty, PerNasty, Alternate, Tit4Tat, Tit4Tat, WinStayLoseShift, Alternate, WinStayLoseShift, PerNasty, RandomNasty, Theresa, Tit4Tat, Alternate]
# out2mutation： [PerNasty, Tit4Tat, WinStayLoseShift, WinStayLoseShift, Dirk, PerKind, Cooperate, Dirk, Cooperate, PerKind, PerKind, RandomNasty, Alternate, Cooperate, PerNasty, PerKind, Cooperate, Betray, PerKind, RandomKind, PerNasty, Alternate, PerKind, PerKind, RandomKind, Alternate, Dirk]
# persons： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, RandomNasty, PerNasty, PerNasty, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, WinStayLoseShift, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, PerNasty, PerNasty, Betray, RandomNasty, WinStayLoseShift, Betray, RandomNasty, PerNasty, Betray, Betray, Betray, Betray, WinStayLoseShift, Betray, RandomNasty, PerNasty, RandomNasty, Betray, Alternate, Betray, Alternate, RandomNasty, Betray, RandomNasty, WinStayLoseShift, WinStayLoseShift, RandomNasty, PerNasty, PerNasty, Alternate, PerNasty, PerNasty, WinStayLoseShift, PerNasty, PerNasty, Betray, Betray, Alternate, RandomNasty, PerNasty, Alternate, RandomNasty, RandomNasty, RandomNasty, PerNasty, Alternate, WinStayLoseShift, RandomNasty, PerNasty, WinStayLoseShift, RandomNasty, RandomNasty, PerNasty, PerNasty, PerNasty, RandomNasty, PerNasty, WinStayLoseShift, WinStayLoseShift, Alternate, PerNasty, Alternate, Alternate, Alternate, Alternate, WinStayLoseShift, WinStayLoseShift, Alternate, PerNasty, WinStayLoseShift, Alternate, RandomNasty, Alternate, RandomNasty, Alternate, Alternate, PerNasty, WinStayLoseShift, Tit4Tat, WinStayLoseShift, PerNasty, WinStayLoseShift, Alternate, RandomNasty, WinStayLoseShift, Alternate, WinStayLoseShift, PerNasty, WinStayLoseShift, Alternate, Tit4Tat, WinStayLoseShift, WinStayLoseShift, Alternate, RandomNasty, PerNasty, Tit4Tat, PerNasty, PerNasty, WinStayLoseShift, RandomNasty, RandomKind, PerNasty, Theresa, WinStayLoseShift, Tit4Tat, WinStayLoseShift, RandomNasty, Tit4Tat, Alternate, WinStayLoseShift, PerNasty, RandomNasty, Dirk, RandomNasty, WinStayLoseShift, Tit4Tat, PerNasty, RandomNasty, RandomKind, Theresa, Alternate, Tit4Tat, Alternate, Alternate, RandomKind, Alternate, Alternate, WinStayLoseShift, Tit4Tat, WinStayLoseShift, Tit4Tat, Alternate, Tit4Tat, Theresa, Alternate, RandomNasty, Tit4Tat, PerNasty, RandomNasty, PerNasty, Alternate, Tit4Tat, Tit4Tat, WinStayLoseShift, Alternate, WinStayLoseShift, PerNasty, RandomNasty, Theresa, Tit4Tat, Alternate, Theresa, PerKind, RandomNasty, Theresa, Alternate, WinStayLoseShift, RandomNasty, Tit4Tat, Theresa, PerNasty, Tit4Tat, Tit4Tat, PerNasty, RandomKind, RandomNasty, Tit4Tat, RandomNasty, RandomNasty, WinStayLoseShift, Dirk, Alternate, Tit4Tat, Alternate, Theresa, RandomKind, RandomNasty, Tit4Tat, WinStayLoseShift, Alternate, PerKind, Alternate, Dirk, Dirk, RandomKind, Dirk, Dirk, PerKind, RandomKind, PerKind, Tit4Tat, WinStayLoseShift, RandomNasty, Alternate, Tit4Tat, Alternate, PerKind, PerKind, WinStayLoseShift, Theresa, PerKind, PerKind, RandomNasty, PerKind, Tit4Tat, RandomKind, PerKind, WinStayLoseShift, WinStayLoseShift, PerKind, Tit4Tat, PerKind, Dirk, PerKind, RandomKind, Theresa, PerKind, RandomKind, PerKind, RandomKind, RandomNasty, Theresa, Tit4Tat, Tit4Tat, WinStayLoseShift, Theresa, PerKind, Dirk, Alternate, Tit4Tat, Tit4Tat, RandomKind, Theresa, Theresa, PerKind, Alternate, Theresa, Dirk, Dirk, PerKind, RandomKind, PerKind, Theresa, Dirk, RandomKind, RandomKind, PerKind, PerKind, Alternate, RandomKind, WinStayLoseShift, RandomKind, PerKind, RandomKind, PerKind, PerKind, RandomKind, Dirk, Dirk, PerKind, PerKind, RandomKind, RandomKind, RandomKind, Dirk, Dirk, Dirk, Theresa, Theresa, Theresa, PerKind, RandomKind, Theresa, Theresa, Dirk, PerKind, Dirk, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Cooperate]
# 3 代, 0 期
# 3 代, 1 期
# 3 代, 2 期
# 3 代, 3 期
# 3 代, 4 期
# 3 代, 5 期
# 3 代, 6 期
# 3 代, 7 期
# 3 代, 8 期
# 3 代, 9 期
# 3 代, 10 期
# 3 代, 11 期
# 3 代, 12 期
# 3 代, 13 期
# 3 代, 14 期
# 3 代, 15 期
# 3 代, 16 期
# 3 代, 17 期
# 3 代, 18 期
# 3 代, 19 期
# out2reinit： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, RandomNasty, Betray, Betray, Betray, PerNasty, Betray, RandomNasty, Betray, PerNasty, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, RandomNasty, Betray, WinStayLoseShift, Betray, Betray, Betray, RandomNasty, RandomNasty, Betray, Betray, RandomNasty, WinStayLoseShift, PerNasty, PerNasty, Betray, PerNasty, RandomNasty, PerNasty, PerNasty, WinStayLoseShift, Betray, PerNasty, Alternate, PerNasty, RandomNasty, WinStayLoseShift, PerNasty, RandomNasty, RandomNasty, Betray, WinStayLoseShift, PerNasty, PerNasty, RandomNasty, PerNasty, WinStayLoseShift, RandomNasty, PerNasty, WinStayLoseShift, Alternate, Alternate, PerNasty, Alternate, Alternate, PerNasty, WinStayLoseShift, Alternate, PerNasty, PerNasty, Tit4Tat, Alternate, PerNasty, PerNasty, WinStayLoseShift, PerNasty, Alternate, RandomNasty, RandomNasty, RandomNasty, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, RandomNasty, PerNasty, Alternate, RandomNasty, PerNasty, WinStayLoseShift, RandomNasty, RandomNasty, WinStayLoseShift, RandomNasty, PerNasty, WinStayLoseShift, Alternate, Alternate, WinStayLoseShift, Tit4Tat, WinStayLoseShift, Alternate, RandomNasty, Tit4Tat, WinStayLoseShift, RandomNasty, Alternate, Alternate, RandomNasty, WinStayLoseShift, PerNasty, WinStayLoseShift, PerNasty, Alternate, Tit4Tat, Alternate, RandomNasty, WinStayLoseShift, WinStayLoseShift, Tit4Tat, Tit4Tat, Alternate, PerNasty, PerNasty, WinStayLoseShift, Alternate, Alternate, WinStayLoseShift, PerNasty, RandomNasty, Alternate, WinStayLoseShift, PerNasty, Alternate, Alternate, WinStayLoseShift, RandomNasty, Alternate, RandomKind, RandomNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, Tit4Tat, Tit4Tat, Tit4Tat, Alternate, PerNasty, PerNasty, Alternate, RandomNasty, PerKind, Dirk, Tit4Tat, Alternate, PerKind, Alternate, WinStayLoseShift, PerNasty, WinStayLoseShift, WinStayLoseShift, PerNasty, PerNasty, Tit4Tat, Tit4Tat, Tit4Tat, Tit4Tat, Tit4Tat, Alternate, WinStayLoseShift, RandomNasty]
# out2mutation： [Dirk, Betray, PerNasty, Dirk, Betray, RandomNasty, Theresa, RandomNasty, Dirk, Tit4Tat, Cooperate, Cooperate, Alternate, PerKind, Cooperate, RandomNasty, Alternate, WinStayLoseShift, RandomNasty, Betray, Alternate, Betray, Theresa, PerNasty, WinStayLoseShift, RandomKind, WinStayLoseShift]
# persons： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, RandomNasty, Betray, Betray, Betray, PerNasty, Betray, RandomNasty, Betray, PerNasty, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, RandomNasty, Betray, WinStayLoseShift, Betray, Betray, Betray, RandomNasty, RandomNasty, Betray, Betray, RandomNasty, WinStayLoseShift, PerNasty, PerNasty, Betray, PerNasty, RandomNasty, PerNasty, PerNasty, WinStayLoseShift, Betray, PerNasty, Alternate, PerNasty, RandomNasty, WinStayLoseShift, PerNasty, RandomNasty, RandomNasty, Betray, WinStayLoseShift, PerNasty, PerNasty, RandomNasty, PerNasty, WinStayLoseShift, RandomNasty, PerNasty, WinStayLoseShift, Alternate, Alternate, PerNasty, Alternate, Alternate, PerNasty, WinStayLoseShift, Alternate, PerNasty, PerNasty, Tit4Tat, Alternate, PerNasty, PerNasty, WinStayLoseShift, PerNasty, Alternate, RandomNasty, RandomNasty, RandomNasty, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, RandomNasty, PerNasty, Alternate, RandomNasty, PerNasty, WinStayLoseShift, RandomNasty, RandomNasty, WinStayLoseShift, RandomNasty, PerNasty, WinStayLoseShift, Alternate, Alternate, WinStayLoseShift, Tit4Tat, WinStayLoseShift, Alternate, RandomNasty, Tit4Tat, WinStayLoseShift, RandomNasty, Alternate, Alternate, RandomNasty, WinStayLoseShift, PerNasty, WinStayLoseShift, PerNasty, Alternate, Tit4Tat, Alternate, RandomNasty, WinStayLoseShift, WinStayLoseShift, Tit4Tat, Tit4Tat, Alternate, PerNasty, PerNasty, WinStayLoseShift, Alternate, Alternate, WinStayLoseShift, PerNasty, RandomNasty, Alternate, WinStayLoseShift, PerNasty, Alternate, Alternate, WinStayLoseShift, RandomNasty, Alternate, RandomKind, RandomNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, Tit4Tat, Tit4Tat, Tit4Tat, Alternate, PerNasty, PerNasty, Alternate, RandomNasty, PerKind, Dirk, Tit4Tat, Alternate, PerKind, Alternate, WinStayLoseShift, PerNasty, WinStayLoseShift, WinStayLoseShift, PerNasty, PerNasty, Tit4Tat, Tit4Tat, Tit4Tat, Tit4Tat, Tit4Tat, Alternate, WinStayLoseShift, RandomNasty, Dirk, Alternate, RandomKind, Alternate, RandomNasty, PerKind, WinStayLoseShift, RandomNasty, Alternate, Tit4Tat, WinStayLoseShift, Theresa, RandomNasty, Theresa, Tit4Tat, WinStayLoseShift, PerKind, PerKind, RandomNasty, RandomKind, WinStayLoseShift, WinStayLoseShift, Dirk, PerKind, WinStayLoseShift, Tit4Tat, Tit4Tat, PerKind, Theresa, Alternate, Dirk, PerKind, Tit4Tat, Tit4Tat, Theresa, Dirk, Tit4Tat, Alternate, PerKind, Tit4Tat, RandomNasty, RandomKind, RandomNasty, PerKind, Alternate, Alternate, Alternate, Theresa, Tit4Tat, Dirk, RandomKind, Tit4Tat, Alternate, PerKind, Dirk, Dirk, Tit4Tat, Tit4Tat, PerKind, PerKind, RandomNasty, Theresa, Alternate, RandomKind, Theresa, RandomKind, RandomKind, Tit4Tat, PerKind, Alternate, WinStayLoseShift, Theresa, RandomKind, RandomKind, RandomKind, RandomKind, Theresa, Alternate, Theresa, Theresa, Alternate, RandomKind, PerKind, PerKind, PerKind, PerKind, PerKind, Dirk, PerKind, Dirk, Dirk, RandomKind, PerKind, Dirk, Theresa, Theresa, Dirk, Theresa, PerKind, RandomKind, Dirk, Theresa, Theresa, PerKind, RandomKind, RandomKind, PerKind, Dirk, Theresa, Dirk, RandomKind, RandomKind, Theresa, Theresa, RandomKind, PerKind, Dirk, PerKind, RandomKind, PerKind, Theresa, RandomKind, PerKind, Theresa, RandomKind, Dirk, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Cooperate]
# 4 代, 0 期
# 4 代, 1 期
# 4 代, 2 期
# 4 代, 3 期
# 4 代, 4 期
# 4 代, 5 期
# 4 代, 6 期
# 4 代, 7 期
# 4 代, 8 期
# 4 代, 9 期
# 4 代, 10 期
# 4 代, 11 期
# 4 代, 12 期
# 4 代, 13 期
# 4 代, 14 期
# 4 代, 15 期
# 4 代, 16 期
# 4 代, 17 期
# 4 代, 18 期
# 4 代, 19 期
# out2reinit： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, PerNasty, Betray, RandomNasty, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, RandomNasty, Betray, Betray, PerNasty, RandomNasty, Betray, WinStayLoseShift, Betray, RandomNasty, PerNasty, RandomNasty, WinStayLoseShift, PerNasty, PerNasty, PerNasty, Betray, Betray, PerNasty, RandomNasty, PerNasty, RandomNasty, WinStayLoseShift, PerNasty, PerNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, PerNasty, Betray, WinStayLoseShift, WinStayLoseShift, PerNasty, RandomNasty, WinStayLoseShift, RandomNasty, RandomNasty, WinStayLoseShift, Alternate, PerNasty, Alternate, PerNasty, PerNasty, Tit4Tat, Alternate, PerNasty, RandomNasty, WinStayLoseShift, RandomNasty, Alternate, PerNasty, Alternate, Alternate, RandomNasty, WinStayLoseShift, RandomNasty, Alternate, RandomNasty, RandomNasty, Tit4Tat, PerNasty, RandomNasty, PerNasty, PerNasty, PerNasty, RandomNasty, RandomNasty, Alternate, PerNasty, Alternate, WinStayLoseShift, Alternate, PerNasty, PerNasty, Alternate, PerNasty, RandomNasty, WinStayLoseShift, RandomNasty, PerNasty, Alternate, WinStayLoseShift, Alternate, Alternate, RandomNasty, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, PerNasty, Alternate, WinStayLoseShift, RandomNasty, Alternate, WinStayLoseShift, RandomNasty, PerNasty, WinStayLoseShift, PerNasty, WinStayLoseShift, PerNasty, Alternate, PerNasty, WinStayLoseShift, Alternate, RandomNasty, RandomNasty, Tit4Tat, WinStayLoseShift, Alternate, PerNasty, Tit4Tat, Alternate, Tit4Tat, Dirk, WinStayLoseShift, Alternate, RandomNasty, WinStayLoseShift, Tit4Tat, Alternate, Alternate, Alternate, RandomNasty, Alternate, Alternate, Tit4Tat, Alternate, PerNasty, Dirk, PerKind, Alternate, Tit4Tat, RandomNasty, Tit4Tat, RandomKind, Tit4Tat, Tit4Tat, WinStayLoseShift, Tit4Tat, RandomNasty, PerNasty, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, Tit4Tat, WinStayLoseShift, Alternate, RandomKind]
# out2mutation： [Cooperate, RandomKind, Dirk, RandomNasty, WinStayLoseShift, Cooperate, Betray, Alternate, Tit4Tat, PerKind, Betray, Theresa, Theresa, PerKind, Betray, Alternate, PerNasty, WinStayLoseShift, RandomNasty, RandomKind, WinStayLoseShift, Dirk, RandomNasty, PerKind, Betray, Betray, Alternate]
# persons： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, PerNasty, Betray, RandomNasty, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, RandomNasty, Betray, Betray, PerNasty, RandomNasty, Betray, WinStayLoseShift, Betray, RandomNasty, PerNasty, RandomNasty, WinStayLoseShift, PerNasty, PerNasty, PerNasty, Betray, Betray, PerNasty, RandomNasty, PerNasty, RandomNasty, WinStayLoseShift, PerNasty, PerNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, PerNasty, Betray, WinStayLoseShift, WinStayLoseShift, PerNasty, RandomNasty, WinStayLoseShift, RandomNasty, RandomNasty, WinStayLoseShift, Alternate, PerNasty, Alternate, PerNasty, PerNasty, Tit4Tat, Alternate, PerNasty, RandomNasty, WinStayLoseShift, RandomNasty, Alternate, PerNasty, Alternate, Alternate, RandomNasty, WinStayLoseShift, RandomNasty, Alternate, RandomNasty, RandomNasty, Tit4Tat, PerNasty, RandomNasty, PerNasty, PerNasty, PerNasty, RandomNasty, RandomNasty, Alternate, PerNasty, Alternate, WinStayLoseShift, Alternate, PerNasty, PerNasty, Alternate, PerNasty, RandomNasty, WinStayLoseShift, RandomNasty, PerNasty, Alternate, WinStayLoseShift, Alternate, Alternate, RandomNasty, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, PerNasty, Alternate, WinStayLoseShift, RandomNasty, Alternate, WinStayLoseShift, RandomNasty, PerNasty, WinStayLoseShift, PerNasty, WinStayLoseShift, PerNasty, Alternate, PerNasty, WinStayLoseShift, Alternate, RandomNasty, RandomNasty, Tit4Tat, WinStayLoseShift, Alternate, PerNasty, Tit4Tat, Alternate, Tit4Tat, Dirk, WinStayLoseShift, Alternate, RandomNasty, WinStayLoseShift, Tit4Tat, Alternate, Alternate, Alternate, RandomNasty, Alternate, Alternate, Tit4Tat, Alternate, PerNasty, Dirk, PerKind, Alternate, Tit4Tat, RandomNasty, Tit4Tat, RandomKind, Tit4Tat, Tit4Tat, WinStayLoseShift, Tit4Tat, RandomNasty, PerNasty, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, Tit4Tat, WinStayLoseShift, Alternate, RandomKind, Alternate, PerKind, Tit4Tat, RandomNasty, WinStayLoseShift, PerNasty, Tit4Tat, RandomKind, WinStayLoseShift, WinStayLoseShift, Tit4Tat, Dirk, Alternate, RandomNasty, PerKind, WinStayLoseShift, WinStayLoseShift, Alternate, Tit4Tat, Alternate, Tit4Tat, Tit4Tat, WinStayLoseShift, Dirk, Tit4Tat, PerKind, RandomNasty, Tit4Tat, PerKind, Tit4Tat, RandomNasty, Tit4Tat, Dirk, Alternate, Dirk, PerKind, Alternate, Alternate, Alternate, Alternate, WinStayLoseShift, Alternate, RandomNasty, PerKind, RandomNasty, Tit4Tat, Theresa, Alternate, PerKind, RandomKind, Tit4Tat, PerKind, Dirk, RandomKind, Tit4Tat, Tit4Tat, PerKind, Dirk, PerKind, Theresa, PerKind, PerKind, RandomKind, PerKind, Theresa, PerKind, Tit4Tat, Alternate, Theresa, PerKind, PerKind, Theresa, Theresa, Theresa, Dirk, PerKind, PerKind, Theresa, Theresa, RandomKind, PerKind, RandomKind, Dirk, RandomKind, Dirk, Dirk, RandomKind, RandomKind, RandomKind, Theresa, RandomKind, PerKind, Dirk, Theresa, Dirk, PerKind, Dirk, Dirk, RandomKind, RandomKind, PerKind, Theresa, RandomKind, Dirk, Theresa, RandomKind, PerKind, RandomKind, PerKind, PerKind, Theresa, Theresa, Theresa, RandomKind, RandomKind, PerKind, Theresa, RandomKind, Theresa, Theresa, PerKind, Theresa, Theresa, Theresa, RandomKind, Theresa, Theresa, Dirk, RandomKind, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Cooperate]
# 5 代, 0 期
# 5 代, 1 期
# 5 代, 2 期
# 5 代, 3 期
# 5 代, 4 期
# 5 代, 5 期
# 5 代, 6 期
# 5 代, 7 期
# 5 代, 8 期
# 5 代, 9 期
# 5 代, 10 期
# 5 代, 11 期
# 5 代, 12 期
# 5 代, 13 期
# 5 代, 14 期
# 5 代, 15 期
# 5 代, 16 期
# 5 代, 17 期
# 5 代, 18 期
# 5 代, 19 期
# out2reinit： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, PerNasty, Betray, Betray, Betray, Betray, Betray, RandomNasty, PerNasty, Betray, RandomNasty, Betray, Betray, Betray, RandomNasty, RandomNasty, Betray, RandomNasty, Betray, WinStayLoseShift, WinStayLoseShift, RandomNasty, WinStayLoseShift, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, Betray, PerNasty, PerNasty, Betray, RandomNasty, RandomNasty, PerNasty, RandomNasty, Alternate, PerNasty, PerNasty, WinStayLoseShift, PerNasty, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, PerNasty, RandomNasty, PerNasty, PerNasty, PerNasty, Alternate, RandomNasty, Alternate, Tit4Tat, RandomNasty, WinStayLoseShift, Alternate, WinStayLoseShift, Alternate, PerNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, RandomNasty, Alternate, WinStayLoseShift, PerNasty, WinStayLoseShift, RandomNasty, RandomNasty, Alternate, PerNasty, WinStayLoseShift, WinStayLoseShift, PerNasty, Alternate, RandomNasty, RandomNasty, RandomNasty, RandomNasty, WinStayLoseShift, RandomNasty, Alternate, PerNasty, RandomNasty, PerNasty, WinStayLoseShift, Tit4Tat, Alternate, RandomNasty, Alternate, RandomNasty, Alternate, PerNasty, Alternate, WinStayLoseShift, WinStayLoseShift, PerNasty, WinStayLoseShift, RandomNasty, PerNasty, PerNasty, Tit4Tat, PerNasty, RandomNasty, RandomNasty, Alternate, Alternate, Alternate, PerNasty, WinStayLoseShift, PerNasty, Tit4Tat, RandomNasty, WinStayLoseShift, Tit4Tat, PerNasty, WinStayLoseShift, Alternate, PerNasty, WinStayLoseShift, Tit4Tat, Alternate, Tit4Tat, Alternate, WinStayLoseShift, WinStayLoseShift, Alternate, RandomNasty, Tit4Tat, WinStayLoseShift, WinStayLoseShift, RandomNasty, RandomNasty, WinStayLoseShift, WinStayLoseShift, Alternate, WinStayLoseShift, Alternate, Tit4Tat, Alternate, Tit4Tat, Tit4Tat, Alternate, Alternate, WinStayLoseShift, Tit4Tat, RandomNasty, WinStayLoseShift, Alternate, Alternate, Dirk, Tit4Tat, Alternate, Dirk, RandomNasty]
# out2mutation： [Tit4Tat, Tit4Tat, Tit4Tat, PerNasty, WinStayLoseShift, RandomNasty, RandomKind, Cooperate, WinStayLoseShift, Cooperate, WinStayLoseShift, WinStayLoseShift, Tit4Tat, Theresa, Betray, Theresa, Cooperate, Alternate, Theresa, PerKind, Betray, Alternate, Theresa, PerNasty, Dirk, Betray, Dirk]
# persons： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, PerNasty, Betray, Betray, Betray, Betray, Betray, RandomNasty, PerNasty, Betray, RandomNasty, Betray, Betray, Betray, RandomNasty, RandomNasty, Betray, RandomNasty, Betray, WinStayLoseShift, WinStayLoseShift, RandomNasty, WinStayLoseShift, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, Betray, PerNasty, PerNasty, Betray, RandomNasty, RandomNasty, PerNasty, RandomNasty, Alternate, PerNasty, PerNasty, WinStayLoseShift, PerNasty, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, PerNasty, RandomNasty, PerNasty, PerNasty, PerNasty, Alternate, RandomNasty, Alternate, Tit4Tat, RandomNasty, WinStayLoseShift, Alternate, WinStayLoseShift, Alternate, PerNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, RandomNasty, Alternate, WinStayLoseShift, PerNasty, WinStayLoseShift, RandomNasty, RandomNasty, Alternate, PerNasty, WinStayLoseShift, WinStayLoseShift, PerNasty, Alternate, RandomNasty, RandomNasty, RandomNasty, RandomNasty, WinStayLoseShift, RandomNasty, Alternate, PerNasty, RandomNasty, PerNasty, WinStayLoseShift, Tit4Tat, Alternate, RandomNasty, Alternate, RandomNasty, Alternate, PerNasty, Alternate, WinStayLoseShift, WinStayLoseShift, PerNasty, WinStayLoseShift, RandomNasty, PerNasty, PerNasty, Tit4Tat, PerNasty, RandomNasty, RandomNasty, Alternate, Alternate, Alternate, PerNasty, WinStayLoseShift, PerNasty, Tit4Tat, RandomNasty, WinStayLoseShift, Tit4Tat, PerNasty, WinStayLoseShift, Alternate, PerNasty, WinStayLoseShift, Tit4Tat, Alternate, Tit4Tat, Alternate, WinStayLoseShift, WinStayLoseShift, Alternate, RandomNasty, Tit4Tat, WinStayLoseShift, WinStayLoseShift, RandomNasty, RandomNasty, WinStayLoseShift, WinStayLoseShift, Alternate, WinStayLoseShift, Alternate, Tit4Tat, Alternate, Tit4Tat, Tit4Tat, Alternate, Alternate, WinStayLoseShift, Tit4Tat, RandomNasty, WinStayLoseShift, Alternate, Alternate, Dirk, Tit4Tat, Alternate, Dirk, RandomNasty, PerKind, RandomKind, Alternate, Tit4Tat, Alternate, WinStayLoseShift, Tit4Tat, Tit4Tat, Tit4Tat, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, PerKind, RandomNasty, Tit4Tat, Alternate, Dirk, PerKind, Tit4Tat, RandomNasty, Alternate, RandomNasty, Alternate, Tit4Tat, Alternate, PerKind, Tit4Tat, RandomKind, Dirk, RandomKind, Alternate, RandomKind, Alternate, WinStayLoseShift, WinStayLoseShift, PerKind, Alternate, Alternate, Tit4Tat, Tit4Tat, Alternate, PerKind, Tit4Tat, Tit4Tat, Dirk, Tit4Tat, PerKind, Dirk, Alternate, RandomNasty, PerKind, PerKind, PerKind, Dirk, Tit4Tat, PerKind, Alternate, PerKind, PerKind, PerKind, PerKind, PerKind, Dirk, PerKind, PerKind, PerKind, RandomKind, Dirk, Tit4Tat, RandomKind, RandomKind, Theresa, Dirk, Theresa, PerKind, PerKind, Theresa, Theresa, PerKind, RandomKind, RandomKind, Dirk, RandomKind, Dirk, Dirk, Dirk, PerKind, Theresa, Theresa, Theresa, RandomKind, Dirk, Dirk, Theresa, RandomKind, RandomKind, Theresa, PerKind, Theresa, RandomKind, RandomKind, Theresa, PerKind, RandomKind, PerKind, Theresa, Theresa, RandomKind, Dirk, PerKind, RandomKind, RandomKind, RandomKind, RandomKind, Theresa, Theresa, Theresa, Theresa, Theresa, PerKind, RandomKind, Theresa, Dirk, RandomKind, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Cooperate]
# 6 代, 0 期
# 6 代, 1 期
# 6 代, 2 期
# 6 代, 3 期
# 6 代, 4 期
# 6 代, 5 期
# 6 代, 6 期
# 6 代, 7 期
# 6 代, 8 期
# 6 代, 9 期
# 6 代, 10 期
# 6 代, 11 期
# 6 代, 12 期
# 6 代, 13 期
# 6 代, 14 期
# 6 代, 15 期
# 6 代, 16 期
# 6 代, 17 期
# 6 代, 18 期
# 6 代, 19 期
# out2reinit： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, PerNasty, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, RandomNasty, RandomNasty, WinStayLoseShift, PerNasty, RandomNasty, WinStayLoseShift, PerNasty, RandomNasty, Betray, PerNasty, PerNasty, RandomNasty, WinStayLoseShift, RandomNasty, RandomNasty, Betray, PerNasty, PerNasty, PerNasty, PerNasty, RandomNasty, PerNasty, PerNasty, WinStayLoseShift, WinStayLoseShift, PerNasty, PerNasty, PerNasty, PerNasty, WinStayLoseShift, PerNasty, RandomNasty, PerNasty, RandomNasty, WinStayLoseShift, Alternate, PerNasty, RandomNasty, Tit4Tat, PerNasty, PerNasty, RandomNasty, Alternate, PerNasty, WinStayLoseShift, WinStayLoseShift, Alternate, Alternate, RandomNasty, Alternate, PerNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, WinStayLoseShift, RandomNasty, RandomNasty, Alternate, WinStayLoseShift, RandomNasty, RandomNasty, PerNasty, RandomNasty, Alternate, RandomNasty, PerNasty, Alternate, PerNasty, PerNasty, RandomNasty, PerNasty, RandomNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, WinStayLoseShift, Alternate, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, Alternate, Alternate, WinStayLoseShift, PerNasty, WinStayLoseShift, Alternate, Alternate, WinStayLoseShift, WinStayLoseShift, PerNasty, WinStayLoseShift, Alternate, Alternate, PerNasty, PerNasty, Tit4Tat, WinStayLoseShift, PerNasty, Tit4Tat, Tit4Tat, Alternate, Tit4Tat, Tit4Tat, Dirk, Alternate, WinStayLoseShift, Alternate, Tit4Tat, RandomNasty, WinStayLoseShift, RandomNasty, RandomNasty, Alternate, RandomNasty, RandomNasty, PerNasty, RandomNasty, RandomNasty, Alternate, Alternate, Tit4Tat, PerNasty, WinStayLoseShift, WinStayLoseShift, RandomNasty, Dirk, Alternate, WinStayLoseShift, Tit4Tat, WinStayLoseShift, PerNasty, WinStayLoseShift, WinStayLoseShift, Tit4Tat, Alternate, Tit4Tat, RandomNasty, Alternate, Tit4Tat, Alternate, WinStayLoseShift, Alternate, Tit4Tat, Alternate, RandomNasty]
# out2mutation： [Betray, RandomNasty, Dirk, RandomNasty, Betray, Alternate, RandomKind, Betray, Dirk, RandomNasty, Cooperate, Tit4Tat, Cooperate, Alternate, WinStayLoseShift, PerKind, RandomNasty, PerKind, Alternate, Tit4Tat, Cooperate, PerKind, RandomKind, Theresa, Theresa, Dirk, PerKind]
# persons： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, PerNasty, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, RandomNasty, RandomNasty, WinStayLoseShift, PerNasty, RandomNasty, WinStayLoseShift, PerNasty, RandomNasty, Betray, PerNasty, PerNasty, RandomNasty, WinStayLoseShift, RandomNasty, RandomNasty, Betray, PerNasty, PerNasty, PerNasty, PerNasty, RandomNasty, PerNasty, PerNasty, WinStayLoseShift, WinStayLoseShift, PerNasty, PerNasty, PerNasty, PerNasty, WinStayLoseShift, PerNasty, RandomNasty, PerNasty, RandomNasty, WinStayLoseShift, Alternate, PerNasty, RandomNasty, Tit4Tat, PerNasty, PerNasty, RandomNasty, Alternate, PerNasty, WinStayLoseShift, WinStayLoseShift, Alternate, Alternate, RandomNasty, Alternate, PerNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, WinStayLoseShift, RandomNasty, RandomNasty, Alternate, WinStayLoseShift, RandomNasty, RandomNasty, PerNasty, RandomNasty, Alternate, RandomNasty, PerNasty, Alternate, PerNasty, PerNasty, RandomNasty, PerNasty, RandomNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, WinStayLoseShift, Alternate, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, Alternate, Alternate, WinStayLoseShift, PerNasty, WinStayLoseShift, Alternate, Alternate, WinStayLoseShift, WinStayLoseShift, PerNasty, WinStayLoseShift, Alternate, Alternate, PerNasty, PerNasty, Tit4Tat, WinStayLoseShift, PerNasty, Tit4Tat, Tit4Tat, Alternate, Tit4Tat, Tit4Tat, Dirk, Alternate, WinStayLoseShift, Alternate, Tit4Tat, RandomNasty, WinStayLoseShift, RandomNasty, RandomNasty, Alternate, RandomNasty, RandomNasty, PerNasty, RandomNasty, RandomNasty, Alternate, Alternate, Tit4Tat, PerNasty, WinStayLoseShift, WinStayLoseShift, RandomNasty, Dirk, Alternate, WinStayLoseShift, Tit4Tat, WinStayLoseShift, PerNasty, WinStayLoseShift, WinStayLoseShift, Tit4Tat, Alternate, Tit4Tat, RandomNasty, Alternate, Tit4Tat, Alternate, WinStayLoseShift, Alternate, Tit4Tat, Alternate, RandomNasty, Tit4Tat, Alternate, Tit4Tat, Alternate, RandomNasty, Tit4Tat, Alternate, Tit4Tat, Alternate, Tit4Tat, WinStayLoseShift, Alternate, WinStayLoseShift, Tit4Tat, RandomNasty, Tit4Tat, Tit4Tat, Dirk, RandomNasty, PerKind, PerKind, PerKind, Alternate, PerKind, Tit4Tat, WinStayLoseShift, Dirk, RandomKind, Alternate, Alternate, RandomKind, Tit4Tat, Tit4Tat, WinStayLoseShift, PerKind, Alternate, Alternate, Alternate, Tit4Tat, RandomKind, RandomNasty, Alternate, Dirk, Theresa, PerKind, Tit4Tat, Tit4Tat, PerKind, RandomKind, WinStayLoseShift, PerKind, Alternate, Dirk, Dirk, PerKind, RandomKind, PerKind, Dirk, PerKind, Tit4Tat, Alternate, PerKind, PerKind, PerKind, RandomKind, PerKind, PerKind, Dirk, PerKind, Theresa, PerKind, PerKind, PerKind, RandomKind, RandomKind, RandomKind, PerKind, RandomKind, PerKind, Dirk, Dirk, Dirk, RandomKind, Theresa, Theresa, PerKind, RandomKind, Theresa, Dirk, Theresa, PerKind, Dirk, RandomKind, RandomKind, Dirk, Dirk, PerKind, Theresa, RandomKind, RandomKind, Dirk, PerKind, Theresa, Theresa, PerKind, Theresa, Theresa, RandomKind, Theresa, Theresa, RandomKind, RandomKind, Theresa, RandomKind, Dirk, RandomKind, Theresa, Theresa, RandomKind, Theresa, PerKind, Theresa, RandomKind, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Cooperate]
# 7 代, 0 期
# 7 代, 1 期
# 7 代, 2 期
# 7 代, 3 期
# 7 代, 4 期
# 7 代, 5 期
# 7 代, 6 期
# 7 代, 7 期
# 7 代, 8 期
# 7 代, 9 期
# 7 代, 10 期
# 7 代, 11 期
# 7 代, 12 期
# 7 代, 13 期
# 7 代, 14 期
# 7 代, 15 期
# 7 代, 16 期
# 7 代, 17 期
# 7 代, 18 期
# 7 代, 19 期
# out2reinit： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, PerNasty, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, PerNasty, PerNasty, RandomNasty, WinStayLoseShift, PerNasty, Betray, Betray, RandomNasty, RandomNasty, Betray, PerNasty, RandomNasty, PerNasty, PerNasty, WinStayLoseShift, RandomNasty, PerNasty, WinStayLoseShift, PerNasty, PerNasty, WinStayLoseShift, WinStayLoseShift, RandomNasty, RandomNasty, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, WinStayLoseShift, RandomNasty, PerNasty, WinStayLoseShift, WinStayLoseShift, Alternate, WinStayLoseShift, PerNasty, Alternate, PerNasty, RandomNasty, PerNasty, Alternate, RandomNasty, PerNasty, PerNasty, WinStayLoseShift, PerNasty, RandomNasty, Tit4Tat, RandomNasty, RandomNasty, RandomNasty, PerNasty, RandomNasty, RandomNasty, WinStayLoseShift, WinStayLoseShift, PerNasty, RandomNasty, Alternate, WinStayLoseShift, PerNasty, RandomNasty, WinStayLoseShift, Alternate, Alternate, RandomNasty, Alternate, PerNasty, Alternate, WinStayLoseShift, RandomNasty, Alternate, PerNasty, PerNasty, Alternate, RandomNasty, Alternate, PerNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, PerNasty, WinStayLoseShift, RandomNasty, PerNasty, WinStayLoseShift, Tit4Tat, Alternate, Tit4Tat, Alternate, PerNasty, Alternate, WinStayLoseShift, Tit4Tat, Tit4Tat, Tit4Tat, WinStayLoseShift, Alternate, Alternate, WinStayLoseShift, PerNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, Tit4Tat, RandomNasty, WinStayLoseShift, Alternate, Alternate, Alternate, Alternate, Tit4Tat, PerNasty, RandomNasty, Dirk, RandomNasty, RandomNasty, Dirk, PerNasty, WinStayLoseShift, WinStayLoseShift, Alternate, Tit4Tat, Tit4Tat, WinStayLoseShift, WinStayLoseShift, Alternate, RandomNasty, WinStayLoseShift, Alternate, RandomNasty, Tit4Tat, RandomNasty, RandomNasty, Alternate, RandomNasty, RandomNasty, Alternate, WinStayLoseShift, Tit4Tat, Tit4Tat, Alternate]
# out2mutation： [Dirk, WinStayLoseShift, RandomNasty, Dirk, Tit4Tat, Theresa, Betray, Dirk, Cooperate, Tit4Tat, Dirk, WinStayLoseShift, PerKind, PerNasty, Theresa, PerNasty, Dirk, PerNasty, RandomNasty, RandomKind, Theresa, Alternate, Dirk, RandomKind, RandomNasty, PerKind, Alternate]
# persons： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, PerNasty, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, PerNasty, PerNasty, RandomNasty, WinStayLoseShift, PerNasty, Betray, Betray, RandomNasty, RandomNasty, Betray, PerNasty, RandomNasty, PerNasty, PerNasty, WinStayLoseShift, RandomNasty, PerNasty, WinStayLoseShift, PerNasty, PerNasty, WinStayLoseShift, WinStayLoseShift, RandomNasty, RandomNasty, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, WinStayLoseShift, RandomNasty, PerNasty, WinStayLoseShift, WinStayLoseShift, Alternate, WinStayLoseShift, PerNasty, Alternate, PerNasty, RandomNasty, PerNasty, Alternate, RandomNasty, PerNasty, PerNasty, WinStayLoseShift, PerNasty, RandomNasty, Tit4Tat, RandomNasty, RandomNasty, RandomNasty, PerNasty, RandomNasty, RandomNasty, WinStayLoseShift, WinStayLoseShift, PerNasty, RandomNasty, Alternate, WinStayLoseShift, PerNasty, RandomNasty, WinStayLoseShift, Alternate, Alternate, RandomNasty, Alternate, PerNasty, Alternate, WinStayLoseShift, RandomNasty, Alternate, PerNasty, PerNasty, Alternate, RandomNasty, Alternate, PerNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, PerNasty, WinStayLoseShift, RandomNasty, PerNasty, WinStayLoseShift, Tit4Tat, Alternate, Tit4Tat, Alternate, PerNasty, Alternate, WinStayLoseShift, Tit4Tat, Tit4Tat, Tit4Tat, WinStayLoseShift, Alternate, Alternate, WinStayLoseShift, PerNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, Tit4Tat, RandomNasty, WinStayLoseShift, Alternate, Alternate, Alternate, Alternate, Tit4Tat, PerNasty, RandomNasty, Dirk, RandomNasty, RandomNasty, Dirk, PerNasty, WinStayLoseShift, WinStayLoseShift, Alternate, Tit4Tat, Tit4Tat, WinStayLoseShift, WinStayLoseShift, Alternate, RandomNasty, WinStayLoseShift, Alternate, RandomNasty, Tit4Tat, RandomNasty, RandomNasty, Alternate, RandomNasty, RandomNasty, Alternate, WinStayLoseShift, Tit4Tat, Tit4Tat, Alternate, Alternate, Tit4Tat, Tit4Tat, RandomNasty, Tit4Tat, Tit4Tat, RandomNasty, Tit4Tat, Dirk, Alternate, Alternate, WinStayLoseShift, WinStayLoseShift, Alternate, Tit4Tat, Tit4Tat, Alternate, WinStayLoseShift, Alternate, Tit4Tat, Alternate, Tit4Tat, Alternate, Tit4Tat, Alternate, Alternate, Alternate, Alternate, Tit4Tat, WinStayLoseShift, PerKind, RandomKind, Tit4Tat, Dirk, Alternate, PerKind, PerKind, Tit4Tat, RandomKind, PerKind, Tit4Tat, RandomNasty, Alternate, PerKind, Dirk, PerKind, PerKind, WinStayLoseShift, PerKind, RandomKind, Tit4Tat, Dirk, PerKind, PerKind, RandomKind, PerKind, Alternate, PerKind, RandomKind, PerKind, RandomKind, Dirk, PerKind, PerKind, PerKind, Dirk, RandomKind, PerKind, RandomKind, Dirk, Theresa, PerKind, Dirk, PerKind, PerKind, Dirk, Dirk, RandomKind, PerKind, Dirk, Dirk, PerKind, RandomKind, RandomKind, Theresa, Theresa, Dirk, PerKind, PerKind, RandomKind, RandomKind, PerKind, RandomKind, Theresa, PerKind, Theresa, Dirk, Theresa, Dirk, RandomKind, RandomKind, Theresa, PerKind, RandomKind, Theresa, PerKind, Theresa, Theresa, RandomKind, Theresa, Theresa, RandomKind, Dirk, Theresa, Theresa, Theresa, RandomKind, Theresa, Theresa, Theresa, RandomKind, RandomKind, RandomKind, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Cooperate]
# 8 代, 0 期
# 8 代, 1 期
# 8 代, 2 期
# 8 代, 3 期
# 8 代, 4 期
# 8 代, 5 期
# 8 代, 6 期
# 8 代, 7 期
# 8 代, 8 期
# 8 代, 9 期
# 8 代, 10 期
# 8 代, 11 期
# 8 代, 12 期
# 8 代, 13 期
# 8 代, 14 期
# 8 代, 15 期
# 8 代, 16 期
# 8 代, 17 期
# 8 代, 18 期
# 8 代, 19 期
# out2reinit： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, PerNasty, Betray, Betray, Betray, PerNasty, PerNasty, Betray, RandomNasty, RandomNasty, WinStayLoseShift, PerNasty, RandomNasty, PerNasty, WinStayLoseShift, PerNasty, WinStayLoseShift, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, RandomNasty, PerNasty, PerNasty, RandomNasty, PerNasty, WinStayLoseShift, PerNasty, PerNasty, RandomNasty, WinStayLoseShift, PerNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, PerNasty, RandomNasty, RandomNasty, PerNasty, RandomNasty, WinStayLoseShift, Alternate, RandomNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, WinStayLoseShift, PerNasty, RandomNasty, RandomNasty, PerNasty, Alternate, PerNasty, Alternate, PerNasty, PerNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, WinStayLoseShift, RandomNasty, PerNasty, PerNasty, WinStayLoseShift, PerNasty, RandomNasty, WinStayLoseShift, Alternate, WinStayLoseShift, RandomNasty, WinStayLoseShift, RandomNasty, Alternate, Tit4Tat, RandomNasty, Alternate, PerNasty, RandomNasty, RandomNasty, PerNasty, Alternate, RandomNasty, WinStayLoseShift, Alternate, WinStayLoseShift, PerNasty, WinStayLoseShift, Tit4Tat, PerNasty, Alternate, Alternate, WinStayLoseShift, PerNasty, WinStayLoseShift, Alternate, WinStayLoseShift, Alternate, Alternate, Tit4Tat, Tit4Tat, WinStayLoseShift, PerNasty, RandomNasty, Tit4Tat, Alternate, PerNasty, Alternate, Alternate, Tit4Tat, WinStayLoseShift, Alternate, WinStayLoseShift, Alternate, RandomNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, Alternate, RandomNasty, PerNasty, Alternate, Tit4Tat, Alternate, RandomNasty, RandomNasty, Tit4Tat, WinStayLoseShift, Tit4Tat, Alternate, Alternate, WinStayLoseShift, RandomNasty, WinStayLoseShift, Tit4Tat, RandomNasty, Alternate, WinStayLoseShift, RandomNasty, RandomNasty, RandomNasty, Tit4Tat, Dirk, Tit4Tat, Alternate, Tit4Tat, Alternate, RandomNasty, Alternate]
# out2mutation： [Dirk, Tit4Tat, Betray, Theresa, Theresa, Alternate, Betray, RandomNasty, Theresa, PerKind, PerNasty, PerNasty, Dirk, PerKind, RandomNasty, Dirk, Betray, WinStayLoseShift, Cooperate, RandomNasty, Cooperate, PerNasty, Tit4Tat, PerKind, RandomKind, RandomNasty, RandomNasty]
# persons： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, PerNasty, Betray, Betray, Betray, PerNasty, PerNasty, Betray, RandomNasty, RandomNasty, WinStayLoseShift, PerNasty, RandomNasty, PerNasty, WinStayLoseShift, PerNasty, WinStayLoseShift, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, RandomNasty, PerNasty, PerNasty, RandomNasty, PerNasty, WinStayLoseShift, PerNasty, PerNasty, RandomNasty, WinStayLoseShift, PerNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, PerNasty, RandomNasty, RandomNasty, PerNasty, RandomNasty, WinStayLoseShift, Alternate, RandomNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, WinStayLoseShift, PerNasty, RandomNasty, RandomNasty, PerNasty, Alternate, PerNasty, Alternate, PerNasty, PerNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, WinStayLoseShift, RandomNasty, PerNasty, PerNasty, WinStayLoseShift, PerNasty, RandomNasty, WinStayLoseShift, Alternate, WinStayLoseShift, RandomNasty, WinStayLoseShift, RandomNasty, Alternate, Tit4Tat, RandomNasty, Alternate, PerNasty, RandomNasty, RandomNasty, PerNasty, Alternate, RandomNasty, WinStayLoseShift, Alternate, WinStayLoseShift, PerNasty, WinStayLoseShift, Tit4Tat, PerNasty, Alternate, Alternate, WinStayLoseShift, PerNasty, WinStayLoseShift, Alternate, WinStayLoseShift, Alternate, Alternate, Tit4Tat, Tit4Tat, WinStayLoseShift, PerNasty, RandomNasty, Tit4Tat, Alternate, PerNasty, Alternate, Alternate, Tit4Tat, WinStayLoseShift, Alternate, WinStayLoseShift, Alternate, RandomNasty, WinStayLoseShift, RandomNasty, WinStayLoseShift, Alternate, RandomNasty, PerNasty, Alternate, Tit4Tat, Alternate, RandomNasty, RandomNasty, Tit4Tat, WinStayLoseShift, Tit4Tat, Alternate, Alternate, WinStayLoseShift, RandomNasty, WinStayLoseShift, Tit4Tat, RandomNasty, Alternate, WinStayLoseShift, RandomNasty, RandomNasty, RandomNasty, Tit4Tat, Dirk, Tit4Tat, Alternate, Tit4Tat, Alternate, RandomNasty, Alternate, Alternate, Alternate, RandomNasty, Dirk, Dirk, WinStayLoseShift, Alternate, Alternate, Alternate, Tit4Tat, WinStayLoseShift, Tit4Tat, Tit4Tat, Tit4Tat, Tit4Tat, Tit4Tat, WinStayLoseShift, Alternate, Alternate, Tit4Tat, Alternate, Alternate, Tit4Tat, Tit4Tat, Alternate, Tit4Tat, Tit4Tat, Tit4Tat, Alternate, WinStayLoseShift, PerKind, Tit4Tat, WinStayLoseShift, WinStayLoseShift, RandomKind, Alternate, Alternate, PerKind, PerKind, Tit4Tat, RandomNasty, Dirk, Dirk, PerKind, PerKind, Tit4Tat, RandomKind, RandomKind, PerKind, RandomKind, Alternate, PerKind, PerKind, PerKind, PerKind, RandomKind, PerKind, PerKind, PerKind, Dirk, PerKind, RandomKind, PerKind, RandomKind, PerKind, PerKind, Dirk, Dirk, PerKind, RandomKind, Dirk, PerKind, Dirk, RandomKind, RandomKind, Dirk, PerKind, Dirk, PerKind, PerKind, Dirk, Theresa, Dirk, RandomKind, RandomKind, PerKind, Theresa, RandomKind, Theresa, Theresa, PerKind, PerKind, RandomKind, Dirk, Dirk, PerKind, Theresa, RandomKind, RandomKind, Theresa, Theresa, RandomKind, Dirk, Theresa, Dirk, RandomKind, PerKind, Theresa, Theresa, RandomKind, Theresa, PerKind, RandomKind, Theresa, Theresa, RandomKind, RandomKind, Theresa, RandomKind, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Cooperate]
# 9 代, 0 期
# 9 代, 1 期
# 9 代, 2 期
# 9 代, 3 期
# 9 代, 4 期
# 9 代, 5 期
# 9 代, 6 期
# 9 代, 7 期
# 9 代, 8 期
# 9 代, 9 期
# 9 代, 10 期
# 9 代, 11 期
# 9 代, 12 期
# 9 代, 13 期
# 9 代, 14 期
# 9 代, 15 期
# 9 代, 16 期
# 9 代, 17 期
# 9 代, 18 期
# 9 代, 19 期
# out2reinit： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, PerNasty, Betray, PerNasty, RandomNasty, PerNasty, PerNasty, PerNasty, RandomNasty, WinStayLoseShift, RandomNasty, PerNasty, WinStayLoseShift, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, RandomNasty, WinStayLoseShift, RandomNasty, PerNasty, PerNasty, PerNasty, PerNasty, WinStayLoseShift, RandomNasty, RandomNasty, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, PerNasty, WinStayLoseShift, WinStayLoseShift, RandomNasty, RandomNasty, Alternate, PerNasty, PerNasty, Alternate, RandomNasty, Alternate, RandomNasty, RandomNasty, WinStayLoseShift, PerNasty, WinStayLoseShift, RandomNasty, Alternate, RandomNasty, PerNasty, RandomNasty, WinStayLoseShift, PerNasty, RandomNasty, PerNasty, Alternate, WinStayLoseShift, PerNasty, WinStayLoseShift, PerNasty, Alternate, RandomNasty, RandomNasty, WinStayLoseShift, WinStayLoseShift, PerNasty, RandomNasty, WinStayLoseShift, WinStayLoseShift, RandomNasty, WinStayLoseShift, PerNasty, WinStayLoseShift, RandomNasty, PerNasty, RandomNasty, Alternate, WinStayLoseShift, WinStayLoseShift, RandomNasty, Alternate, Alternate, Alternate, WinStayLoseShift, PerNasty, Alternate, Alternate, RandomNasty, Alternate, Tit4Tat, WinStayLoseShift, RandomNasty, WinStayLoseShift, Alternate, Tit4Tat, WinStayLoseShift, Tit4Tat, PerNasty, PerNasty, RandomNasty, RandomNasty, WinStayLoseShift, Alternate, RandomNasty, PerNasty, RandomNasty, Alternate, RandomNasty, WinStayLoseShift, Tit4Tat, RandomNasty, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, Alternate, Tit4Tat, Alternate, RandomNasty, Tit4Tat, Tit4Tat, WinStayLoseShift, Alternate, Alternate, RandomNasty, Tit4Tat, Tit4Tat, RandomNasty, WinStayLoseShift, Tit4Tat, Dirk, Alternate, Tit4Tat, Alternate, Alternate, Tit4Tat, RandomNasty, Tit4Tat, Alternate, WinStayLoseShift, Alternate, Tit4Tat]
# out2mutation： [Cooperate, Dirk, RandomKind, Alternate, Alternate, RandomNasty, Tit4Tat, WinStayLoseShift, RandomNasty, Cooperate, Betray, RandomNasty, Alternate, RandomKind, WinStayLoseShift, RandomNasty, Theresa, Theresa, RandomNasty, PerNasty, PerKind, Theresa, Dirk, RandomKind, PerNasty, WinStayLoseShift, RandomKind]
# persons： [Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, Betray, PerNasty, Betray, PerNasty, RandomNasty, PerNasty, PerNasty, PerNasty, RandomNasty, WinStayLoseShift, RandomNasty, PerNasty, WinStayLoseShift, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, PerNasty, RandomNasty, WinStayLoseShift, RandomNasty, PerNasty, PerNasty, PerNasty, PerNasty, WinStayLoseShift, RandomNasty, RandomNasty, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, PerNasty, WinStayLoseShift, WinStayLoseShift, RandomNasty, RandomNasty, Alternate, PerNasty, PerNasty, Alternate, RandomNasty, Alternate, RandomNasty, RandomNasty, WinStayLoseShift, PerNasty, WinStayLoseShift, RandomNasty, Alternate, RandomNasty, PerNasty, RandomNasty, WinStayLoseShift, PerNasty, RandomNasty, PerNasty, Alternate, WinStayLoseShift, PerNasty, WinStayLoseShift, PerNasty, Alternate, RandomNasty, RandomNasty, WinStayLoseShift, WinStayLoseShift, PerNasty, RandomNasty, WinStayLoseShift, WinStayLoseShift, RandomNasty, WinStayLoseShift, PerNasty, WinStayLoseShift, RandomNasty, PerNasty, RandomNasty, Alternate, WinStayLoseShift, WinStayLoseShift, RandomNasty, Alternate, Alternate, Alternate, WinStayLoseShift, PerNasty, Alternate, Alternate, RandomNasty, Alternate, Tit4Tat, WinStayLoseShift, RandomNasty, WinStayLoseShift, Alternate, Tit4Tat, WinStayLoseShift, Tit4Tat, PerNasty, PerNasty, RandomNasty, RandomNasty, WinStayLoseShift, Alternate, RandomNasty, PerNasty, RandomNasty, Alternate, RandomNasty, WinStayLoseShift, Tit4Tat, RandomNasty, WinStayLoseShift, WinStayLoseShift, WinStayLoseShift, Alternate, Tit4Tat, Alternate, RandomNasty, Tit4Tat, Tit4Tat, WinStayLoseShift, Alternate, Alternate, RandomNasty, Tit4Tat, Tit4Tat, RandomNasty, WinStayLoseShift, Tit4Tat, Dirk, Alternate, Tit4Tat, Alternate, Alternate, Tit4Tat, RandomNasty, Tit4Tat, Alternate, WinStayLoseShift, Alternate, Tit4Tat, Dirk, WinStayLoseShift, Tit4Tat, Tit4Tat, Tit4Tat, Tit4Tat, Tit4Tat, Alternate, Alternate, Alternate, Tit4Tat, Alternate, WinStayLoseShift, WinStayLoseShift, Tit4Tat, WinStayLoseShift, Dirk, Alternate, Alternate, WinStayLoseShift, Alternate, Alternate, Tit4Tat, Alternate, Tit4Tat, Alternate, Tit4Tat, Tit4Tat, RandomNasty, Alternate, Alternate, RandomKind, RandomNasty, Tit4Tat, Alternate, Alternate, Alternate, Dirk, Tit4Tat, Tit4Tat, PerKind, PerKind, PerKind, RandomKind, PerKind, RandomKind, RandomKind, Dirk, PerKind, PerKind, PerKind, RandomKind, PerKind, PerKind, PerKind, PerKind, RandomKind, Alternate, Dirk, PerKind, PerKind, PerKind, RandomKind, PerKind, PerKind, PerKind, Dirk, Dirk, PerKind, RandomKind, PerKind, PerKind, Dirk, RandomKind, Dirk, PerKind, RandomKind, Dirk, PerKind, RandomKind, Dirk, Dirk, Dirk, RandomKind, PerKind, RandomKind, RandomKind, PerKind, PerKind, Dirk, PerKind, Dirk, Theresa, RandomKind, RandomKind, Theresa, Theresa, Dirk, Theresa, RandomKind, Dirk, Theresa, PerKind, Theresa, RandomKind, Theresa, Theresa, RandomKind, PerKind, Theresa, RandomKind, RandomKind, Theresa, RandomKind, Theresa, Theresa, RandomKind, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Theresa, Cooperate]
# {'Tit4Tat': [50, 43, 43, 43, 44, 42, 45, 43, 43, 43], 'Theresa': [50, 50, 46, 35, 33, 33, 35, 33, 34, 34], 'WinStayLoseShift': [50, 66, 66, 71, 74, 74, 76, 74, 75, 73], 'Dirk': [50, 25, 21, 22, 22, 22, 22, 23, 26, 22], 'Alternate': [50, 74, 70, 75, 72, 73, 71, 71, 69, 69], 'PerNasty': [50, 61, 70, 71, 72, 70, 72, 70, 73, 73], 'Cooperate': [50, 2, 7, 5, 4, 3, 4, 4, 2, 3], 'PerKind': [50, 41, 32, 35, 31, 32, 29, 32, 30, 31], 'RandomNasty': [50, 62, 63, 66, 71, 71, 71, 74, 74, 77], 'RandomKind': [50, 34, 29, 28, 25, 27, 24, 25, 25, 24], 'Betray': [50, 92, 103, 99, 102, 103, 101, 101, 99, 101]}
# {'PerKind': 3366.2903225806454, 'WinStayLoseShift': 2416.931506849315, 'RandomNasty': 2226.0779220779223, 'Tit4Tat': 2744.860465116279, 'Betray': 2658.6138613861385, 'Theresa': 3027.323529411765, 'RandomKind': 3464.7083333333335, 'PerNasty': 2288.6849315068494, 'Alternate': 2557.6376811594205, 'Dirk': 3102.3636363636365, 'Cooperate': 1072.0}

# %% [markdown]
# ## 三、结论分析

# %% [markdown]
# <p style="text-indent:2em">从样本选择分布可以看到，经过十轮迭代后，有超过半数的样本选择了背叛（True）；从样本分布可以看到，在众多复杂的策略中，最终没未淘汰样本最多的为背叛策略，即永远选择背叛（True）；从策略趋势图中可以看出，在众多复杂的策略中，合作策略的样本数量下降的最快，背叛策略的样本数量上升的最快，且最终背叛策略以显著的优势占据了绝大多数样本数量。该沙盒模型最终得出的结论与囚徒困境结论相同，即个人最佳选择并非团体最佳选择，随着迭代次数的增加，团体最佳的选择出现的次数会越来越多</p>
